# %%
class BinaryTree:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


        
        
def printTree(root):
    if root == None:
        return 
    print(root.data,end=":")
    if root.left != None:
        print("L",root.left.data, end = ",")
    if root.right != None:
        print("R",root.right.data, end = "")
    print("")
    printTree(root.left)
    printTree(root.right)
    

def TakeInput():
    user = int(input())
    if user == -1:
        return None
    root = BinaryTree(user)
    leftTree = TakeInput()
    rightTree = TakeInput()
    root.left = leftTree
    root.right= rightTree
    return root
    
min_f = 10000
max_f = -10000

def isBST(root):
    global min_f
    global max_f
    
    if root == None:
        return min_f, max_f, True
    min_f, max_f, lbst = isBST(root.left)
    min_f,max_f, rbst = isBST(root.right)
    
    if max_f<root.data:
        max_f = root.data
    else:
        lbst = False
    if min_f>root.data:
        min_f = root.data
    else:
        rbst = False
    if lbst and rbst:
        return  min_f, max_f, True
    else:
        return min_f, max_f, False
    
    
        
        
        
#Main

root = TakeInput()
x = int(input())
#calling Print fun
printTree(root)
lmax, rmin, ibst = isBST(root)
print(ibst)
# Out:
# 4
# 2
# 1
# -1
# -1
# 10
# -1
# -1
# 6
# 7
# -1
# -1
# 8
# -1
# -1
# -1
# 4:L 2,R 6
# 2:L 1,R 10
# 1:
# 10:
# 6:L 7,R 8
# 7:
# 8:
# False

# %% [markdown]
# #
