# %%
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
class BST:
    
    def __init__(self):
        self.root = None
        self.numNodes = 0
    
    def printTreeHelper(self, root):
        if root == None:
            return
        print(root.data, end = ":")
        if root.left != None:
            print("L:",end='')
            print(root.left.data,end=',')
        if root.right != None:
            print("R:",end='')
            print(root.right.data,end='')
        print()
        self.printTreeHelper(root.left)
        self.printTreeHelper(root.right)
    
    def printTree(self):
        self.printTreeHelper(self.root)
    
    def isSearchHelper(self, root, data):
        
        if root == None:
            return False
        if root.data == data:
            return True

        if root.data >data:
            return self.isSearchHelper(root.left,data)
        if root.data <=data:
            return self.isSearchHelper(root.right, data)

    

    def insertHelper(self, root, data):
        if root == None:
            root = BinaryTreeNode(data)
            return root
        if root.data>data:
            root.left = self.insertHelper(root.left, data)
            return root
        if root.data<=data:
            root.right = self.insertHelper(root.right, data)
            return root
    
    def search(self, data):
    #Implement this function here
        return self.isSearchHelper(self.root, data)
        
    def insert(self, data):
    #Implement this function here
        self.numNodes += 1
        self.root =  self.insertHelper(self.root, data)
    
    def min_node(self, root):
        if root == None:
            return 10000
        if root.left == None:
            return root.data
        return self.min_node(root.left)
    
    def deleteHelper(self, root, data):

        if root == None:
            return False, None
        if root.data>data:
            flagL, newLeft = self.deleteHelper(root.left, data)
            root.left = newLeft
            return flagL,root 
        if root.data<data:
            flagR, newRight = self.deleteHelper(root.right, data)
            root.right = newRight
            return flagR, root
        if root.data == data:
            if root.left == None and root.right == None:
                return True,None
            
            if root.left!=None and root.right ==None:
                return True, root.left
            if root.right!=None and root.left ==None:
                return True, root.right
            if root.left !=None and root.right!=None:
                replacement = self.min_node(root.right)
                root.data = replacement
                flag, Rhead = self.deleteHelper(root.right, replacement)
                root.right = Rhead
                return True, root
    
    
    def delete(self, data):
        
        flag, newRoot =  self.deleteHelper(self.root, data)
        
        if flag == True:
            self.numNodes -= 1
        self.root = newRoot
        
        return flag
    
    
    def count(self):
        return self.numNodes
b = BST()
li = [int(ele) for ele in input().split()]
i = 0
while(i < (len(li) )):
    choice = li[i]
    if choice == 1:
        data = li[i+1]
        b.insert(data)
        i+=2
    elif choice == 2:
        data = li[i+1]
        b.delete(data)
        i+=2
    elif choice == 3:
        data = li[i+1]
        ans = b.search(data)
        if ans is True:
            print('true')
        else:
            print('false')
        i+=2
    else:
        b.printTree()
        i+=1
# Out:
# 1 20 1 40 1 10 1 30 1 70 1 15 1 65 1 35 1 25 3 40 2 40 3 40 3 65 -1
# true
# false
# true
# 20:L:10,R:65
# 10:R:15
# 15:
# 65:L:30,R:70
# 30:L:25,R:35
# 25:
# 35:
# 70:
