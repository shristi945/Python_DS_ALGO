# %%
class Stack:
    def __init__(self):
        self.__arr = []


    def push_stk(self,ele):
        self.__arr.append(ele)
        print(self.__arr)
    def pop_stk(self):
        if self.isEmpty():
            print("Stack is Empty!")
            return
        return self.__arr.pop()
        
    def top_stk(self):
        if self.isEmpty():
            print("Stack is Empty!")
            return 
        return  self.__arr[-1]
        
        return ele
    def size_stk(self):
        l = len(self.__arr)
        return l
    def isEmpty(self):
        return self.size_stk()==0



#main
user_input = '0'
s = Stack()
while user_input is not '6':
    print("Enter you Choice:")
    print("1: Push elements", "\n2: Pop elements", "\n3: Find top", "\n4: Find size", "\n5: Find stack is empty or not", "\n6 To Quit")
    user_input = input()
    if user_input == '1':
        print("Please enter element to push:")
        ele = input()
        s.push_stk(ele)
    elif user_input == '2':
        ele = s.pop_stk()
        print("Element poped:", ele)
    elif user_input == '3':
        ele = s.top_stk()
        print("top elemnt:", ele )
    elif user_input == '4':
        print(s.size_stk())
    elif user_input == '5':
        res = s.isEmpty()
        if res == True:
            print("yes")
        else: 
            print("No")
print("Thank You:)")
# Out:
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 1
# Please enter element to push:
# 5
# ['5']
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 1
# Please enter element to push:
# 88
# ['5', '88']
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 1
# Please enter element to push:
# 9
# ['5', '88', '9']
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 2
# Element poped: 9
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 4
# 2
# Enter you Choice:
# 1: Push elements
# 2: Pop elements
# 3: Find top
# 4: Find size
# 5: Find stack is empty or not
# 6 To Quit
# 5
# No
# ...
