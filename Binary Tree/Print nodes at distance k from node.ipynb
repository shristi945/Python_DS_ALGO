# %%
class BinaryTree:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


        
        
def printTree(root):
    if root == None:
        return 
    print(root.data,end=":")
    if root.left != None:
        print("L",root.left.data, end = ",")
    if root.right != None:
        print("R",root.right.data, end = "")
    print("")
    printTree(root.left)
    printTree(root.right)
    

def TakeInput():
    user = int(input())
    if user == -1:
        return None
    root = BinaryTree(user)
    leftTree = TakeInput()
    rightTree = TakeInput()
    root.left = leftTree
    root.right= rightTree
    return root
    
def find(root, data, k):
    if root == None:
        return 
    if root.data == None:
        for ele in range(k):
            root = root.left
        print(root.data)
        
        
    else:
        find(root.left)
        find(root.right)
    

        
        
#Main
print("Enter K:")
k=int(input())
root = TakeInput()
x = int(input())
#calling Print fun
# rootToLeafPathsSumToK(root, k, [])
# printTree(root)
